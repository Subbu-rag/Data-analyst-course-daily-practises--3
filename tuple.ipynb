# %%
tuples=()
print(tuples)
print(type(tuples))
# Out:
# ()
# <class 'tuple'>

# %%
numbers=tuple([2,3,4,5,6,7])
print(numbers)
# Out:
# (2, 3, 4, 5, 6, 7)

# %%
list((1,2,3,4,5))
# Out:
# [1, 2, 3, 4, 5]

# %%
mixed_tuple=((1,"Sting",3.12,True))
print(mixed_tuple)
# Out:
# (1, 'Sting', 3.12, True)

# %%
numbers
# Out:
# (2, 3, 4, 5, 6, 7)

# %%
numbers[2]
# Out:
# 4

# %%
concatenation_tuple=mixed_tuple+numbers
print(concatenation_tuple)
# Out:
# (1, 'Sting', 3.12, True, 2, 3, 4, 5, 6, 7)

# %%
mixed_tuple*3
# Out:
# (1, 'Sting', 3.12, True, 1, 'Sting', 3.12, True, 1, 'Sting', 3.12, True)

# %%
numbers*3
# Out:
# (2, 3, 4, 5, 6, 7, 2, 3, 4, 5, 6, 7, 2, 3, 4, 5, 6, 7)

# %%
## Immutable Nature Of Tuples
## Tuples are immutable, meaning their elements cannot be changed once assigned.
numbers[1]="krish"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 ## Immutable Nature Of Tuples
#       2 ## Tuples are immutable, meaning their elements cannot be changed once assigned.
# ----> 3 numbers[1]="krish"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Tuple methods
print(numbers.count(1))
print(numbers.index(3))
# Out:
# 0
# 1

# %%
#packing
packed_tuple=1,"Hello",3.14
print(packed_tuple)
# Out:
# (1, 'Hello', 3.14)

# %%
#unpacking
a,b,c=packed_tuple
print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.14

# %%
#unpacking with *
numbers=(1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
#Nested list
lst=[[1,2,3,4],[5,6,7,8],[1,"hello",3.14]]
lst[0][0:3]
# Out:
# [1, 2, 3]

# %%
lst=[[1,2,3,4],[5,6,7,8],(1,"hello",3.14)]
lst[2][0:3]
# Out:
# (1, 'hello', 3.14)

# %%
nested_tuple=((1,2,3),("a","b","c"),(True,False))
#accessing the elements in the tuple
print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
#iterating over nested tuples
for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item,end=" ")
    print()
# Out:
# 1 2 3
# a b c
# True False
